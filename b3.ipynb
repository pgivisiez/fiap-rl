# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------
# Quantum Finance - Apresentação/Estudo de aplicação em Reinforcement Learning (Turma 8DTSR)
# ------------------------------------------------------------------------------------------------------------------------------------
#
# - O que deve ser apresentado?
#
# Ao final da disciplina deverá ser apresentado o planejamento de uma aplicação ou então pesquisa com relação a um problema em específico, se utilizando de Aprendizagem por Reforço (RL).
#
# O problema a ser solucionado via Reinforcement Learning é o seguinte:
#
# A QuantumFinance deseja criar um fundo automatizado para operar três ativos: Vale, Petrobrás e Brasil Foods. O objetivo é desenvolver e simular um agente de Reinforcement Learning (RL) capaz de tomar decisões financeiras, como compra, venda ou manutenção de posição, com base em dados históricos.
#
# Tarefas:
#
# - Definir o Problema de RL:
# Identificar estados, ações e recompensas no contexto financeiro.
#
# - Implementar ou apresentar exemplo de aplicação do Agente de RL:
# Escolher um algoritmo de RL (ex.: Q-Learning ou DQN) e aplicá-lo para treinar o agente utilizando os dados históricos.
#
# - Avaliação do Desempenho:
# Descrever ou simular o comportamento do agente e, se possível, analisar os resultados com métricas financeiras relevantes (lucro, sharpe ratio, etc.).
#
# - Entregáveis:
# Relatório explicativo com desenho do agente, resultados obtidos e insights;
# Se aplicável, código-fonte com a implementação e simulações realizadas.
#
#
# As equipes devem atentar para os seguintes pontos:
#
# Ingestão de dados - Quais seriam os dados a serem utilizados para resolver o problema em questão, conseguem mostrar exemplos de como estão dispostos esses dados de alguma forma? Há bases que podem ser utilizadas em um problema de RL?
#
# (Dica: pesquisar uma aplicação/problema em algum site de pesquisa de datasets como https://datasetsearch.research.google.com/, https://www.kaggle.com/ ou no https://paperswithcode.com/task/reinforcement-learning-1).
#
# Processamento: Têm exemplos de como esse problema/aplicação tem sido implementado? Que tipo de algoritmo é mais utilizado? Tem como exemplificar o funcionamento de alguma forma?
#
# (Dica: tem muita coisa legal em repositórios no github como  o https://github.com/aikorea/awesome-rl).
#
# Saída do processo: Qual a saída do processo? Qual o objetivo do agente no caso escolhido? Negociar um ativo ao melhor preço? Criar um documento com feedback humano para os analistas?
#
# - Sugiro estruturar o trabalho tendo por base os seguintes tópicos:
#
# Introdução e Problemática;
# Motivação e Objetivo;
# Apresentação da aplicação estudada/estrutura;
# Considerações e Potencial.
#
# - Avaliação:
#
# Material escrito entregue (de preferência slides, vídeo com breve apresentação etc.);
# Aderência aos pontos;
# Avaliação de código/aplicação, se aplicável;
# Originalidade, “fit” para com o perfil do curso/alunos e “doability”.
#
# - Sites para pesquisas quanto a bases de dados:
#
# http://archive.ics.uci.edu/ml/index.php
# http://dados.gov.br/
# https://www.kaggle.com/datasets
# https://github.com/fivethirtyeight/data
# http://www.portaldatransparencia.gov.br/
# https://paperswithcode.com/
# https://datasetsearch.research.google.com/
#
# Mais sobre Aprendizagem por Reforço:
#
# https://towardsdatascience.com/applications-of-reinforcement-learning-in-real-world-1a94955bcd12
# https://wiki.pathmind.com/deep-reinforcement-learning#define
#
# Entrega do trabalho: dia 23/02/2025
#
# Quaisquer dúvidas é só me contactar: profahirton.lopes@fiap.com.br
#
# []'s

# %% [markdown]
# # Preparando dados

# %%
import pandas as pd
import numpy as np

import gymnasium as gym
from gymnasium import spaces

import random

# %%
df = pd.read_csv('b3.csv')

# %%
df.dtypes
# Out:
# codigo_registro                int64
# data_pregao                   object
# codigo_mercado                 int64
# ativo                         object
# codigo_bdi                     int64
# nome                          object
# especificador                 object
# identificacao_mercado         object
# moeda_cotacao                 object
# preco_abertura               float64
# preco_maximo                 float64
# preco_minimo                 float64
# preco_fechamento             float64
# preco_melhor_compra          float64
# preco_melhor_venda           float64
# numero_negocios                int64
# quantidade_acoes               int64
# volume_financeiro            float64
# preco_fechamento_ajustado    float64
# fator_ajuste                   int64
# codigo_papel_registro         object
# dtype: object

# %%
df.head()
# Out:
#    codigo_registro data_pregao  codigo_mercado  ativo  codigo_bdi       nome  \
# 0                1  2022-02-03               2  VALE3          10       VALE
# 1                1  2022-01-03               2  VALE3          10       VALE
# 2                1  2022-02-03               2  PETR4          10  PETROBRAS
# 3                1  2022-02-03               2  BRFS3          10     BRF SA
# 4                1  2022-01-03               2  PETR4          10  PETROBRAS
#
#   especificador identificacao_mercado moeda_cotacao  preco_abertura  ...  \
# 0            ON                    NM            R$           86.30  ...
# 1            ON                    NM            R$           79.00  ...
# 2            PN                    N2            R$           32.35  ...
# 3            ON                    NM            R$           20.01  ...
# 4            PN                    N2            R$           28.54  ...
#
#    preco_minimo  preco_fechamento  preco_melhor_compra  preco_melhor_venda  \
# 0         85.32             86.01                85.75               85.74
# 1         78.00             78.76                78.00               78.00
# 2         31.62             32.03                32.07               32.07
# 3         19.82             19.97                19.85               19.85
# 4         28.53             28.99                29.09               29.08
#
#    numero_negocios  quantidade_acoes  volume_financeiro  \
# 0                0    85755787300000        191794000.0
# 1                0    78047400000000        185572000.0
# 2                0    32089236000000        510878000.0
# 3                0    19864616200000        191324000.0
# 4                0    29098247900000        527047000.0
#
#    preco_fechamento_ajustado  fator_ajuste  \
# 0                16496500.39             0
# 1                14617464.93             0
# 2                16363981.67             0
# 3                 3821164.14             0
# 4                15284293.87             0
#
#                                codigo_papel_registro
# 0  0000000000009999123100000010000000000000BRVALE...
# 1  0000000000009999123100000010000000000000BRVALE...
# 2  0000000000009999123100000010000000000000BRPETR...
# 3  0000000000009999123100000010000000000000BRBRFS...
# 4  0000000000009999123100000010000000000000BRPETR...
#
# [5 rows x 21 columns]

# %% [markdown]
# # Preaprando DataFrame apenas com as features de interesse

# %%
feats = [
    'data_pregao',
    'ativo',
    'preco_abertura',
    'preco_maximo',
    'preco_minimo',
    'preco_fechamento'
]
    
df = df[feats].copy()

# %%
df.head()
# Out:
#   data_pregao  ativo  preco_abertura  preco_maximo  preco_minimo  \
# 0  2022-02-03  VALE3           86.30         86.78         85.32
# 1  2022-01-03  VALE3           79.00         79.97         78.00
# 2  2022-02-03  PETR4           32.35         32.92         31.62
# 3  2022-02-03  BRFS3           20.01         20.30         19.82
# 4  2022-01-03  PETR4           28.54         29.22         28.53
#
#    preco_fechamento
# 0             86.01
# 1             78.76
# 2             32.03
# 3             19.97
# 4             28.99

# %% [markdown]
# # Reinforcement Learning

# %% [markdown]
# ## Preparando ambiente

# %%
class TradingEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, data: pd.DataFrame, window_ma: int = 5, transaction_cost: float = 0.001):
        super().__init__()
        self.data = data.copy()  # DataFrame com índice de datas e colunas: 'VALE3', 'PETR4', 'BRFS3'
        self.dates = self.data.index.tolist()
        self.assets = list(self.data.columns)
        self.n_assets = len(self.assets)
        self.window_ma = window_ma
        self.transaction_cost = transaction_cost
        
        # Calcula a média móvel para cada ativo
        self.ma_data = self.data.rolling(window=self.window_ma, min_periods=1).mean()
        
        # Inicia após ter dados suficientes para MA
        self.current_step = self.window_ma  
        
        # Carteira inicial
        self.initial_cash = 10000.0
        self.cash = self.initial_cash
        self.positions = {asset: 0 for asset in self.assets}
        
        # Espaço de observação: para cada ativo: [diff (0,1,2), indicador (0,1), posição (0,1)]
        low = np.array([0] * (self.n_assets * 3))
        high = np.array([2, 1, 1] * self.n_assets)
        self.observation_space = spaces.Box(low=low, high=high, dtype=np.int32)
        
        # Espaço de ação: para cada ativo: 0 = hold, 1 = buy, 2 = sell
        self.action_space = spaces.MultiDiscrete([3] * self.n_assets)

    def reset(self, seed=None, options=None):
        self.current_step = self.window_ma
        self.cash = self.initial_cash
        self.positions = {asset: 0 for asset in self.assets}
        return self._get_obs(), {}

    def _get_obs(self):
        obs = []
        for asset in self.assets:
            prev_price = self.data.iloc[self.current_step - 1][asset]
            curr_price = self.data.iloc[self.current_step][asset]
            # Diferença discretizada:
            if curr_price > prev_price:
                diff = 2
            elif curr_price < prev_price:
                diff = 0
            else:
                diff = 1
            # Indicador: preço acima da média móvel?
            ma = self.ma_data.iloc[self.current_step][asset]
            above_ma = 1 if curr_price > ma else 0
            pos = self.positions[asset]
            obs.extend([diff, above_ma, pos])
        return np.array(obs, dtype=np.int32)

    def step(self, action):
        current_prices = {asset: self.data.iloc[self.current_step][asset] for asset in self.assets}
        
        # Executa a ação para cada ativo com custo de transação
        for i, asset in enumerate(self.assets):
            act = action[i]
            price = current_prices[asset]
            cost = price * self.transaction_cost
            if act == 1:  # Buy
                if self.positions[asset] == 0 and self.cash >= (price + cost):
                    self.positions[asset] = 1
                    self.cash -= (price + cost)
            elif act == 2:  # Sell
                if self.positions[asset] == 1:
                    self.positions[asset] = 0
                    self.cash += (price - cost)
            # Se hold, nada é feito

        portfolio_value = self.cash + sum(self.positions[asset] * current_prices[asset] for asset in self.assets)
        
        self.current_step += 1
        done = self.current_step >= len(self.data)
        
        if not done:
            next_prices = {asset: self.data.iloc[self.current_step][asset] for asset in self.assets}
        else:
            next_prices = current_prices
        
        new_portfolio_value = self.cash + sum(self.positions[asset] * next_prices[asset] for asset in self.assets)
        reward = new_portfolio_value - portfolio_value
        
        obs = self._get_obs() if not done else np.zeros(self.observation_space.shape, dtype=np.int32)
        info = {"portfolio_value": new_portfolio_value}
        
        return obs, reward, done, False, info

    def render(self):
        print(f"Step: {self.current_step}, Cash: {self.cash:.2f}, Positions: {self.positions}")

# %% [markdown]
# ## Funções para mapeamento de estado/ação

# %% [markdown]
# Converter vetor de estado para índice.
#
# O estado tem 9 features (3 por ativo). Para manter a abordagem tabular, precisamos discretizar ou codificar cada feature.
#
# Aqui, assumimos que:
# - Para cada ativo, diff: {0,1,2}  (3 valores)
# - indicador: {0,1}                (2 valores)
# - posição: {0,1}                  (2 valores)
#
# Portanto, cada ativo tem 3*2*2 = 12 combinações e para 3 ativos, total = 12^3 = 1728 estados.

# %%
def state_to_index(state):
    idx = 0
    multiplier = 1
    for i in range(0, len(state), 3):
        diff, ind, pos = state[i], state[i+1], state[i+2]
        substate = diff + ind * 3 + pos * 6
        idx += substate * multiplier
        multiplier *= 12
    return idx

def action_to_index(action):
    a0, a1, a2 = action
    return a0 + a1 * 3 + a2 * 9

def index_to_action(action_index):
    a0 = action_index % 3
    a1 = (action_index // 3) % 3
    a2 = (action_index // 9) % 3
    return np.array([a0, a1, a2])

# %%
n_states = 1728   # 12^3 estados
n_actions = 27    # 3^3 ações
alpha = 0.1
gamma = 0.95
epsilon = 1.0
min_epsilon = 0.01
epsilon_decay = 0.995

# %%
Q_table = np.random.uniform(low=-0.01, high=0.01, size=(n_states, n_actions))
n_episodes = 2500

# %%
df.head()
# Out:
#   data_pregao  ativo  preco_abertura  preco_maximo  preco_minimo  \
# 0  2022-02-03  VALE3           86.30         86.78         85.32
# 1  2022-01-03  VALE3           79.00         79.97         78.00
# 2  2022-02-03  PETR4           32.35         32.92         31.62
# 3  2022-02-03  BRFS3           20.01         20.30         19.82
# 4  2022-01-03  PETR4           28.54         29.22         28.53
#
#    preco_fechamento
# 0             86.01
# 1             78.76
# 2             32.03
# 3             19.97
# 4             28.99

# %% [markdown]
# ## "Girando" o DataFrame

# %%
df['data_pregao'] = pd.to_datetime(df['data_pregao'])
df_prices = df.pivot(index='data_pregao', columns='ativo', values='preco_fechamento')
df_prices = df_prices.sort_index()
df_prices.head()
# Out:
# ativo        BRFS3  PETR4  VALE3
# data_pregao
# 2022-01-03   22.82  28.99  78.76
# 2022-01-04   22.40  29.18  77.65
# 2022-01-05   23.14  28.52  77.86
# 2022-01-06   23.60  28.21  79.62
# 2022-01-07   24.42  28.07  82.16

# %%
env = TradingEnv(df_prices, window_ma=5, transaction_cost=0.001)

# %%
for episode in range(n_episodes):
    state, _ = env.reset()
    state_idx = state_to_index(state)
    done = False
    total_reward = 0.0

    while not done:
        if random.uniform(0, 1) < epsilon:
            action_idx = random.randint(0, n_actions - 1)
        else:
            action_idx = np.argmax(Q_table[state_idx, :])
        action = index_to_action(action_idx)
        
        next_state, reward, done, truncated, info = env.step(action)
        total_reward += reward
        next_state_idx = state_to_index(next_state) if not done else 0
        
        best_next_action = np.argmax(Q_table[next_state_idx, :])
        Q_table[state_idx, action_idx] += alpha * (reward + gamma * Q_table[next_state_idx, best_next_action] - Q_table[state_idx, action_idx])
        state_idx = next_state_idx

    epsilon = max(min_epsilon, epsilon * epsilon_decay)
    if (episode + 1) % 100 == 0:
        print(f"Episode {episode+1}/{n_episodes} - Total Reward: {total_reward:.2f} - Epsilon: {epsilon:.3f}")

print("Treinamento concluído!")

# %% [markdown]
# # Simulação de teste

# %%
epsilon_test = 0.05  # Permite que, ocasionalmente, uma ação diferente seja escolhida

state, _ = env.reset()
done = False
portfolio_values = [env.cash + sum(env.positions[asset] * env.data.iloc[env.current_step][asset] for asset in env.assets)]
daily_returns = []
trade_log = []  # Para registrar operações
step_counter = 0

while not done:
    step_counter += 1
    state_idx = state_to_index(state)
    # Política epsilon-greedy com epsilon_test
    if random.uniform(0, 1) < epsilon_test:
        action_idx = random.randint(0, n_actions - 1)
    else:
        action_idx = np.argmax(Q_table[state_idx, :])
    action = index_to_action(action_idx)
    
    # Registro de trades (se não hold)
    for i, act in enumerate(action):
        if act != 0:
            trade_log.append({
                "step": step_counter,
                "asset": env.assets[i],
                "action": "Buy" if act == 1 else "Sell",
                "price": env.data.iloc[env.current_step][env.assets[i]],
                "cash_before": env.cash,
                "positions_before": env.positions.copy()
            })
    
    next_state, reward, done, truncated, info = env.step(action)
    
    current_value = info["portfolio_value"]
    portfolio_values.append(current_value)
    daily_returns.append(reward / (portfolio_values[-2] + 1e-8))
    state = next_state

final_value = portfolio_values[-1]
profit = final_value - env.initial_cash
if np.std(daily_returns) > 0:
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) * np.sqrt(252)
else:
    sharpe_ratio = 0.0

print(f"Valor final da carteira: {final_value:.2f}")
print(f"Lucro acumulado: {profit:.2f}")
print(f"Sharpe Ratio: {sharpe_ratio:.2f}")

print("\nTrade Log:")
for trade in trade_log:
    print(trade)
# Out:
# Valor final da carteira: 10166.41
# Lucro acumulado: 166.41
# Sharpe Ratio: 3.97
#
# Trade Log:
# {'step': 1, 'asset': 'PETR4', 'action': 'Sell', 'price': 27.92, 'cash_before': 10000.0, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 1, 'asset': 'VALE3', 'action': 'Buy', 'price': 83.16, 'cash_before': 10000.0, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 2, 'asset': 'PETR4', 'action': 'Buy', 'price': 28.6, 'cash_before': 9916.75684, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 2, 'asset': 'VALE3', 'action': 'Sell', 'price': 84.39, 'cash_before': 9916.75684, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 3, 'asset': 'PETR4', 'action': 'Buy', 'price': 29.53, 'cash_before': 9972.43385, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 3, 'asset': 'VALE3', 'action': 'Buy', 'price': 85.73, 'cash_before': 9972.43385, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 4, 'asset': 'VALE3', 'action': 'Sell', 'price': 84.38, 'cash_before': 9886.61812, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 5, 'asset': 'BRFS3', 'action': 'Buy', 'price': 24.29, 'cash_before': 9970.91374, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 5, 'asset': 'PETR4', 'action': 'Buy', 'price': 31.08, 'cash_before': 9970.91374, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 6, 'asset': 'BRFS3', 'action': 'Sell', 'price': 24.03, 'cash_before': 9946.59945, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 6, 'asset': 'PETR4', 'action': 'Buy', 'price': 31.57, 'cash_before': 9946.59945, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 6, 'asset': 'VALE3', 'action': 'Buy', 'price': 84.28, 'cash_before': 9946.59945, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 7, 'asset': 'PETR4', 'action': 'Buy', 'price': 31.55, 'cash_before': 9886.24114, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 7, 'asset': 'VALE3', 'action': 'Buy', 'price': 86.09, 'cash_before': 9886.24114, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 8, 'asset': 'BRFS3', 'action': 'Sell', 'price': 23.58, 'cash_before': 9886.24114, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 9, 'asset': 'VALE3', 'action': 'Sell', 'price': 87.64, 'cash_before': 9886.24114, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 10, 'asset': 'BRFS3', 'action': 'Buy', 'price': 22.88, 'cash_before': 9973.7935, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 10, 'asset': 'PETR4', 'action': 'Sell', 'price': 31.71, 'cash_before': 9973.7935, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 11, 'asset': 'BRFS3', 'action': 'Sell', 'price': 22.69, 'cash_before': 9982.56891, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 11, 'asset': 'PETR4', 'action': 'Sell', 'price': 31.61, 'cash_before': 9982.56891, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 11, 'asset': 'VALE3', 'action': 'Sell', 'price': 83.07, 'cash_before': 9982.56891, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 12, 'asset': 'VALE3', 'action': 'Buy', 'price': 83.98, 'cash_before': 10005.23622, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 13, 'asset': 'BRFS3', 'action': 'Buy', 'price': 23.05, 'cash_before': 9921.17224, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 13, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.95, 'cash_before': 9921.17224, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 13, 'asset': 'VALE3', 'action': 'Buy', 'price': 85.15, 'cash_before': 9921.17224, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 14, 'asset': 'BRFS3', 'action': 'Buy', 'price': 23.19, 'cash_before': 9864.11524, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 14, 'asset': 'PETR4', 'action': 'Sell', 'price': 33.99, 'cash_before': 9864.11524, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 15, 'asset': 'BRFS3', 'action': 'Sell', 'price': 22.76, 'cash_before': 9898.071249999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 15, 'asset': 'VALE3', 'action': 'Sell', 'price': 84.35, 'cash_before': 9898.071249999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 16, 'asset': 'BRFS3', 'action': 'Buy', 'price': 22.15, 'cash_before': 10005.074139999999, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 16, 'asset': 'VALE3', 'action': 'Sell', 'price': 81.45, 'cash_before': 10005.074139999999, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 17, 'asset': 'BRFS3', 'action': 'Buy', 'price': 21.91, 'cash_before': 9982.901989999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 17, 'asset': 'PETR4', 'action': 'Sell', 'price': 32.83, 'cash_before': 9982.901989999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 17, 'asset': 'VALE3', 'action': 'Buy', 'price': 83.83, 'cash_before': 9982.901989999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 18, 'asset': 'BRFS3', 'action': 'Buy', 'price': 19.95, 'cash_before': 9898.988159999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 18, 'asset': 'PETR4', 'action': 'Sell', 'price': 32.64, 'cash_before': 9898.988159999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 19, 'asset': 'PETR4', 'action': 'Sell', 'price': 32.03, 'cash_before': 9898.988159999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 19, 'asset': 'VALE3', 'action': 'Buy', 'price': 86.01, 'cash_before': 9898.988159999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 20, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.78, 'cash_before': 9898.988159999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 20, 'asset': 'VALE3', 'action': 'Buy', 'price': 87.19, 'cash_before': 9898.988159999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 21, 'asset': 'BRFS3', 'action': 'Buy', 'price': 18.29, 'cash_before': 9866.175379999999, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 21, 'asset': 'PETR4', 'action': 'Sell', 'price': 32.36, 'cash_before': 9866.175379999999, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 22, 'asset': 'PETR4', 'action': 'Sell', 'price': 31.61, 'cash_before': 9898.503019999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 22, 'asset': 'VALE3', 'action': 'Buy', 'price': 90.75, 'cash_before': 9898.503019999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 23, 'asset': 'PETR4', 'action': 'Sell', 'price': 32.22, 'cash_before': 9898.503019999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 24, 'asset': 'BRFS3', 'action': 'Buy', 'price': 19.14, 'cash_before': 9898.503019999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 24, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.53, 'cash_before': 9898.503019999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 24, 'asset': 'VALE3', 'action': 'Sell', 'price': 93.49, 'cash_before': 9898.503019999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 25, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.49, 'cash_before': 9959.337, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 26, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.15, 'cash_before': 9959.337, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 26, 'asset': 'VALE3', 'action': 'Sell', 'price': 91.37, 'cash_before': 9959.337, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 27, 'asset': 'BRFS3', 'action': 'Sell', 'price': 18.98, 'cash_before': 9959.337, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 27, 'asset': 'VALE3', 'action': 'Sell', 'price': 88.88, 'cash_before': 9959.337, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 28, 'asset': 'VALE3', 'action': 'Sell', 'price': 89.74, 'cash_before': 9978.29802, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 29, 'asset': 'BRFS3', 'action': 'Buy', 'price': 18.86, 'cash_before': 9978.29802, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 29, 'asset': 'PETR4', 'action': 'Sell', 'price': 32.81, 'cash_before': 9978.29802, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 29, 'asset': 'VALE3', 'action': 'Sell', 'price': 86.58, 'cash_before': 9978.29802, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 30, 'asset': 'BRFS3', 'action': 'Buy', 'price': 18.94, 'cash_before': 9992.19635, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 30, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.73, 'cash_before': 9992.19635, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 31, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.66, 'cash_before': 9959.43362, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 31, 'asset': 'VALE3', 'action': 'Sell', 'price': 87.05, 'cash_before': 9959.43362, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 32, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.83, 'cash_before': 9959.43362, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 32, 'asset': 'VALE3', 'action': 'Sell', 'price': 86.83, 'cash_before': 9959.43362, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 33, 'asset': 'PETR4', 'action': 'Buy', 'price': 34.27, 'cash_before': 9959.43362, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 33, 'asset': 'VALE3', 'action': 'Buy', 'price': 86.54, 'cash_before': 9959.43362, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 34, 'asset': 'BRFS3', 'action': 'Buy', 'price': 17.27, 'cash_before': 9872.80708, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 34, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.89, 'cash_before': 9872.80708, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 34, 'asset': 'VALE3', 'action': 'Buy', 'price': 85.7, 'cash_before': 9872.80708, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 35, 'asset': 'BRFS3', 'action': 'Buy', 'price': 16.85, 'cash_before': 9872.80708, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 35, 'asset': 'PETR4', 'action': 'Sell', 'price': 33.57, 'cash_before': 9872.80708, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 36, 'asset': 'PETR4', 'action': 'Buy', 'price': 34.81, 'cash_before': 9906.34351, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 36, 'asset': 'VALE3', 'action': 'Buy', 'price': 98.64, 'cash_before': 9906.34351, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 37, 'asset': 'PETR4', 'action': 'Sell', 'price': 34.47, 'cash_before': 9871.4987, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 38, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.51, 'cash_before': 9905.93423, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 38, 'asset': 'PETR4', 'action': 'Sell', 'price': 34.13, 'cash_before': 9905.93423, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 39, 'asset': 'BRFS3', 'action': 'Buy', 'price': 14.74, 'cash_before': 9905.93423, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 39, 'asset': 'PETR4', 'action': 'Sell', 'price': 33.02, 'cash_before': 9905.93423, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 40, 'asset': 'VALE3', 'action': 'Sell', 'price': 102.2, 'cash_before': 9905.93423, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 41, 'asset': 'BRFS3', 'action': 'Buy', 'price': 16.35, 'cash_before': 10008.03203, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 41, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.23, 'cash_before': 10008.03203, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 42, 'asset': 'BRFS3', 'action': 'Sell', 'price': 15.87, 'cash_before': 9975.7698, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 42, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.66, 'cash_before': 9975.7698, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 42, 'asset': 'VALE3', 'action': 'Buy', 'price': 95.92, 'cash_before': 9975.7698, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 43, 'asset': 'PETR4', 'action': 'Sell', 'price': 33.31, 'cash_before': 9895.60801, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 43, 'asset': 'VALE3', 'action': 'Sell', 'price': 97.62, 'cash_before': 9895.60801, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 44, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.36, 'cash_before': 10026.40708, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 44, 'asset': 'VALE3', 'action': 'Sell', 'price': 92.3, 'cash_before': 10026.40708, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 45, 'asset': 'PETR4', 'action': 'Buy', 'price': 31.03, 'cash_before': 10011.03172, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 46, 'asset': 'BRFS3', 'action': 'Buy', 'price': 16.0, 'cash_before': 9979.97069, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 46, 'asset': 'VALE3', 'action': 'Buy', 'price': 91.15, 'cash_before': 9979.97069, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 47, 'asset': 'BRFS3', 'action': 'Buy', 'price': 16.45, 'cash_before': 9888.72954, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 47, 'asset': 'PETR4', 'action': 'Sell', 'price': 30.2, 'cash_before': 9888.72954, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 47, 'asset': 'VALE3', 'action': 'Buy', 'price': 93.96, 'cash_before': 9888.72954, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 48, 'asset': 'PETR4', 'action': 'Buy', 'price': 30.53, 'cash_before': 9918.89934, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 48, 'asset': 'VALE3', 'action': 'Buy', 'price': 95.54, 'cash_before': 9918.89934, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 49, 'asset': 'BRFS3', 'action': 'Sell', 'price': 16.65, 'cash_before': 9888.33881, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 49, 'asset': 'PETR4', 'action': 'Sell', 'price': 31.55, 'cash_before': 9888.33881, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 49, 'asset': 'VALE3', 'action': 'Sell', 'price': 98.52, 'cash_before': 9888.33881, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 50, 'asset': 'BRFS3', 'action': 'Buy', 'price': 17.2, 'cash_before': 10034.91209, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 50, 'asset': 'PETR4', 'action': 'Sell', 'price': 31.6, 'cash_before': 10034.91209, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 50, 'asset': 'VALE3', 'action': 'Sell', 'price': 96.92, 'cash_before': 10034.91209, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 51, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.13, 'cash_before': 10017.69489, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 52, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.27, 'cash_before': 9985.53276, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 52, 'asset': 'VALE3', 'action': 'Sell', 'price': 96.67, 'cash_before': 9985.53276, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 53, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.3, 'cash_before': 9985.53276, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 53, 'asset': 'VALE3', 'action': 'Buy', 'price': 95.64, 'cash_before': 9985.53276, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 54, 'asset': 'BRFS3', 'action': 'Sell', 'price': 17.4, 'cash_before': 9889.79712, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 54, 'asset': 'PETR4', 'action': 'Sell', 'price': 31.52, 'cash_before': 9889.79712, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 55, 'asset': 'BRFS3', 'action': 'Buy', 'price': 18.06, 'cash_before': 9938.6682, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 55, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.3, 'cash_before': 9938.6682, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 56, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.77, 'cash_before': 9888.25784, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 57, 'asset': 'BRFS3', 'action': 'Buy', 'price': 18.5, 'cash_before': 9888.25784, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 57, 'asset': 'PETR4', 'action': 'Sell', 'price': 33.15, 'cash_before': 9888.25784, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 58, 'asset': 'BRFS3', 'action': 'Sell', 'price': 18.78, 'cash_before': 9921.37469, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 58, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.31, 'cash_before': 9921.37469, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 58, 'asset': 'VALE3', 'action': 'Buy', 'price': 96.9, 'cash_before': 9921.37469, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 59, 'asset': 'PETR4', 'action': 'Sell', 'price': 32.59, 'cash_before': 9906.7926, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 59, 'asset': 'VALE3', 'action': 'Sell', 'price': 97.83, 'cash_before': 9906.7926, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 60, 'asset': 'VALE3', 'action': 'Sell', 'price': 96.31, 'cash_before': 10037.08218, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 61, 'asset': 'BRFS3', 'action': 'Buy', 'price': 17.75, 'cash_before': 10037.08218, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 61, 'asset': 'VALE3', 'action': 'Sell', 'price': 96.24, 'cash_before': 10037.08218, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 62, 'asset': 'BRFS3', 'action': 'Sell', 'price': 18.03, 'cash_before': 10019.314429999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 62, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.45, 'cash_before': 10019.314429999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 62, 'asset': 'VALE3', 'action': 'Buy', 'price': 96.58, 'cash_before': 10019.314429999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 63, 'asset': 'BRFS3', 'action': 'Sell', 'price': 17.6, 'cash_before': 9907.166369999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 63, 'asset': 'PETR4', 'action': 'Sell', 'price': 34.21, 'cash_before': 9907.166369999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 63, 'asset': 'VALE3', 'action': 'Buy', 'price': 95.61, 'cash_before': 9907.166369999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 64, 'asset': 'BRFS3', 'action': 'Sell', 'price': 16.42, 'cash_before': 9941.342159999998, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 64, 'asset': 'PETR4', 'action': 'Sell', 'price': 33.94, 'cash_before': 9941.342159999998, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 64, 'asset': 'VALE3', 'action': 'Sell', 'price': 94.04, 'cash_before': 9941.342159999998, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 65, 'asset': 'BRFS3', 'action': 'Buy', 'price': 16.01, 'cash_before': 10035.288119999997, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 66, 'asset': 'VALE3', 'action': 'Sell', 'price': 93.47, 'cash_before': 10019.262109999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 67, 'asset': 'PETR4', 'action': 'Buy', 'price': 31.49, 'cash_before': 10019.262109999998, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 68, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.23, 'cash_before': 9987.740619999999, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 68, 'asset': 'PETR4', 'action': 'Sell', 'price': 30.79, 'cash_before': 9987.740619999999, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 68, 'asset': 'VALE3', 'action': 'Sell', 'price': 90.76, 'cash_before': 9987.740619999999, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 69, 'asset': 'BRFS3', 'action': 'Sell', 'price': 15.38, 'cash_before': 10018.499829999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 69, 'asset': 'PETR4', 'action': 'Buy', 'price': 31.49, 'cash_before': 10018.499829999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 70, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.03, 'cash_before': 10002.34296, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 71, 'asset': 'BRFS3', 'action': 'Buy', 'price': 14.55, 'cash_before': 9987.29793, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 71, 'asset': 'PETR4', 'action': 'Sell', 'price': 30.79, 'cash_before': 9987.29793, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 71, 'asset': 'VALE3', 'action': 'Sell', 'price': 81.62, 'cash_before': 9987.29793, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 72, 'asset': 'PETR4', 'action': 'Buy', 'price': 29.9, 'cash_before': 10018.05714, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 73, 'asset': 'BRFS3', 'action': 'Sell', 'price': 13.65, 'cash_before': 9988.127240000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 73, 'asset': 'PETR4', 'action': 'Buy', 'price': 30.2, 'cash_before': 9988.127240000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 73, 'asset': 'VALE3', 'action': 'Buy', 'price': 78.63, 'cash_before': 9988.127240000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 74, 'asset': 'BRFS3', 'action': 'Buy', 'price': 13.86, 'cash_before': 9923.054960000003, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 74, 'asset': 'PETR4', 'action': 'Buy', 'price': 30.13, 'cash_before': 9923.054960000003, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 74, 'asset': 'VALE3', 'action': 'Buy', 'price': 81.68, 'cash_before': 9923.054960000003, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 75, 'asset': 'BRFS3', 'action': 'Buy', 'price': 14.0, 'cash_before': 9909.181100000003, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 75, 'asset': 'PETR4', 'action': 'Sell', 'price': 30.43, 'cash_before': 9909.181100000003, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 75, 'asset': 'VALE3', 'action': 'Sell', 'price': 83.63, 'cash_before': 9909.181100000003, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 76, 'asset': 'PETR4', 'action': 'Buy', 'price': 31.05, 'cash_before': 10023.127040000003, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 77, 'asset': 'BRFS3', 'action': 'Buy', 'price': 13.22, 'cash_before': 9992.045990000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 77, 'asset': 'PETR4', 'action': 'Sell', 'price': 29.79, 'cash_before': 9992.045990000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 77, 'asset': 'VALE3', 'action': 'Sell', 'price': 81.92, 'cash_before': 9992.045990000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 78, 'asset': 'BRFS3', 'action': 'Sell', 'price': 13.3, 'cash_before': 10021.806200000003, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 78, 'asset': 'PETR4', 'action': 'Buy', 'price': 30.14, 'cash_before': 10021.806200000003, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 79, 'asset': 'BRFS3', 'action': 'Sell', 'price': 13.28, 'cash_before': 10004.922760000003, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 79, 'asset': 'VALE3', 'action': 'Buy', 'price': 80.92, 'cash_before': 10004.922760000003, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 80, 'asset': 'BRFS3', 'action': 'Buy', 'price': 12.5, 'cash_before': 9923.921840000003, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 80, 'asset': 'VALE3', 'action': 'Sell', 'price': 80.41, 'cash_before': 9923.921840000003, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 81, 'asset': 'PETR4', 'action': 'Sell', 'price': 32.73, 'cash_before': 9991.738930000001, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 82, 'asset': 'BRFS3', 'action': 'Buy', 'price': 12.09, 'cash_before': 10024.436200000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 82, 'asset': 'PETR4', 'action': 'Sell', 'price': 32.42, 'cash_before': 10024.436200000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 82, 'asset': 'VALE3', 'action': 'Sell', 'price': 76.9, 'cash_before': 10024.436200000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 83, 'asset': 'BRFS3', 'action': 'Buy', 'price': 12.73, 'cash_before': 10024.436200000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 83, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.51, 'cash_before': 10024.436200000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 83, 'asset': 'VALE3', 'action': 'Buy', 'price': 75.68, 'cash_before': 10024.436200000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 84, 'asset': 'BRFS3', 'action': 'Sell', 'price': 12.47, 'cash_before': 9916.138010000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 84, 'asset': 'PETR4', 'action': 'Sell', 'price': 33.56, 'cash_before': 9916.138010000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 84, 'asset': 'VALE3', 'action': 'Sell', 'price': 78.8, 'cash_before': 9916.138010000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 85, 'asset': 'BRFS3', 'action': 'Buy', 'price': 12.44, 'cash_before': 10040.843180000002, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 85, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.71, 'cash_before': 10040.843180000002, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 85, 'asset': 'VALE3', 'action': 'Sell', 'price': 77.15, 'cash_before': 10040.843180000002, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 86, 'asset': 'PETR4', 'action': 'Buy', 'price': 34.26, 'cash_before': 9994.647030000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 86, 'asset': 'VALE3', 'action': 'Buy', 'price': 78.46, 'cash_before': 9994.647030000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 87, 'asset': 'PETR4', 'action': 'Sell', 'price': 34.65, 'cash_before': 9916.108570000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 88, 'asset': 'PETR4', 'action': 'Buy', 'price': 34.36, 'cash_before': 9950.723920000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 88, 'asset': 'VALE3', 'action': 'Sell', 'price': 80.04, 'cash_before': 9950.723920000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 89, 'asset': 'BRFS3', 'action': 'Sell', 'price': 14.02, 'cash_before': 9996.289520000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 89, 'asset': 'VALE3', 'action': 'Sell', 'price': 77.96, 'cash_before': 9996.289520000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 90, 'asset': 'BRFS3', 'action': 'Buy', 'price': 13.49, 'cash_before': 10010.295500000002, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 90, 'asset': 'PETR4', 'action': 'Sell', 'price': 33.98, 'cash_before': 10010.295500000002, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 90, 'asset': 'VALE3', 'action': 'Buy', 'price': 79.59, 'cash_before': 10010.295500000002, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 91, 'asset': 'PETR4', 'action': 'Buy', 'price': 34.61, 'cash_before': 9951.068440000003, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 91, 'asset': 'VALE3', 'action': 'Buy', 'price': 81.42, 'cash_before': 9951.068440000003, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 92, 'asset': 'PETR4', 'action': 'Sell', 'price': 35.87, 'cash_before': 9916.423830000003, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 93, 'asset': 'BRFS3', 'action': 'Sell', 'price': 14.14, 'cash_before': 9952.257960000003, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 93, 'asset': 'PETR4', 'action': 'Buy', 'price': 31.32, 'cash_before': 9952.257960000003, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 93, 'asset': 'VALE3', 'action': 'Sell', 'price': 82.77, 'cash_before': 9952.257960000003, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 94, 'asset': 'BRFS3', 'action': 'Buy', 'price': 14.18, 'cash_before': 10017.719730000003, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 95, 'asset': 'BRFS3', 'action': 'Sell', 'price': 14.37, 'cash_before': 10003.525550000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 95, 'asset': 'VALE3', 'action': 'Buy', 'price': 84.08, 'cash_before': 10003.525550000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 96, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.11, 'cash_before': 9933.717100000002, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 96, 'asset': 'PETR4', 'action': 'Sell', 'price': 31.02, 'cash_before': 9933.717100000002, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 97, 'asset': 'PETR4', 'action': 'Sell', 'price': 29.77, 'cash_before': 9949.58097, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 97, 'asset': 'VALE3', 'action': 'Sell', 'price': 86.8, 'cash_before': 9949.58097, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 98, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.55, 'cash_before': 10036.294170000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 98, 'asset': 'VALE3', 'action': 'Buy', 'price': 86.05, 'cash_before': 10036.294170000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 99, 'asset': 'BRFS3', 'action': 'Sell', 'price': 15.3, 'cash_before': 9950.158120000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 99, 'asset': 'PETR4', 'action': 'Sell', 'price': 30.05, 'cash_before': 9950.158120000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 99, 'asset': 'VALE3', 'action': 'Sell', 'price': 87.68, 'cash_before': 9950.158120000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 100, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.37, 'cash_before': 10053.035140000002, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 100, 'asset': 'VALE3', 'action': 'Sell', 'price': 89.8, 'cash_before': 10053.035140000002, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 101, 'asset': 'VALE3', 'action': 'Buy', 'price': 88.92, 'cash_before': 10037.649770000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 102, 'asset': 'PETR4', 'action': 'Buy', 'price': 30.22, 'cash_before': 9948.640850000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 102, 'asset': 'VALE3', 'action': 'Buy', 'price': 89.14, 'cash_before': 9948.640850000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 103, 'asset': 'BRFS3', 'action': 'Sell', 'price': 15.06, 'cash_before': 9918.390630000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 103, 'asset': 'PETR4', 'action': 'Buy', 'price': 30.84, 'cash_before': 9918.390630000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 103, 'asset': 'VALE3', 'action': 'Sell', 'price': 90.26, 'cash_before': 9918.390630000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 104, 'asset': 'BRFS3', 'action': 'Sell', 'price': 15.09, 'cash_before': 10023.60531, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 104, 'asset': 'PETR4', 'action': 'Sell', 'price': 30.73, 'cash_before': 10023.60531, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 105, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.09, 'cash_before': 10054.30458, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 105, 'asset': 'VALE3', 'action': 'Sell', 'price': 85.11, 'cash_before': 10054.30458, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 106, 'asset': 'PETR4', 'action': 'Buy', 'price': 29.52, 'cash_before': 10039.19949, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 107, 'asset': 'BRFS3', 'action': 'Buy', 'price': 14.14, 'cash_before': 10009.64997, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 107, 'asset': 'PETR4', 'action': 'Sell', 'price': 29.15, 'cash_before': 10009.64997, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 107, 'asset': 'VALE3', 'action': 'Sell', 'price': 81.59, 'cash_before': 10009.64997, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 108, 'asset': 'BRFS3', 'action': 'Buy', 'price': 13.43, 'cash_before': 10038.77082, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 109, 'asset': 'VALE3', 'action': 'Sell', 'price': 82.49, 'cash_before': 10038.77082, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 110, 'asset': 'PETR4', 'action': 'Buy', 'price': 27.06, 'cash_before': 10038.77082, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 111, 'asset': 'BRFS3', 'action': 'Buy', 'price': 12.55, 'cash_before': 10011.68376, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 111, 'asset': 'PETR4', 'action': 'Sell', 'price': 27.44, 'cash_before': 10011.68376, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 111, 'asset': 'VALE3', 'action': 'Sell', 'price': 75.43, 'cash_before': 10011.68376, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 112, 'asset': 'VALE3', 'action': 'Sell', 'price': 76.65, 'cash_before': 10039.09632, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 113, 'asset': 'BRFS3', 'action': 'Buy', 'price': 13.02, 'cash_before': 10039.09632, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 113, 'asset': 'PETR4', 'action': 'Buy', 'price': 27.04, 'cash_before': 10039.09632, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 114, 'asset': 'BRFS3', 'action': 'Sell', 'price': 13.92, 'cash_before': 10012.02928, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 114, 'asset': 'PETR4', 'action': 'Sell', 'price': 26.65, 'cash_before': 10012.02928, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 114, 'asset': 'VALE3', 'action': 'Buy', 'price': 73.95, 'cash_before': 10012.02928, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 115, 'asset': 'BRFS3', 'action': 'Buy', 'price': 14.21, 'cash_before': 9978.53476, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 115, 'asset': 'PETR4', 'action': 'Sell', 'price': 26.49, 'cash_before': 9978.53476, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 115, 'asset': 'VALE3', 'action': 'Buy', 'price': 74.02, 'cash_before': 9978.53476, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 116, 'asset': 'BRFS3', 'action': 'Buy', 'price': 14.9, 'cash_before': 9964.31055, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 116, 'asset': 'PETR4', 'action': 'Buy', 'price': 27.63, 'cash_before': 9964.31055, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 116, 'asset': 'VALE3', 'action': 'Sell', 'price': 77.76, 'cash_before': 9964.31055, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 117, 'asset': 'PETR4', 'action': 'Sell', 'price': 28.43, 'cash_before': 10014.33516, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 117, 'asset': 'VALE3', 'action': 'Sell', 'price': 79.41, 'cash_before': 10014.33516, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 118, 'asset': 'BRFS3', 'action': 'Sell', 'price': 14.11, 'cash_before': 10042.73673, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 118, 'asset': 'PETR4', 'action': 'Sell', 'price': 28.3, 'cash_before': 10042.73673, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 118, 'asset': 'VALE3', 'action': 'Sell', 'price': 78.99, 'cash_before': 10042.73673, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 119, 'asset': 'PETR4', 'action': 'Buy', 'price': 27.82, 'cash_before': 10056.832620000001, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 120, 'asset': 'PETR4', 'action': 'Buy', 'price': 28.27, 'cash_before': 10028.9848, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 121, 'asset': 'BRFS3', 'action': 'Buy', 'price': 14.78, 'cash_before': 10028.9848, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 121, 'asset': 'PETR4', 'action': 'Buy', 'price': 29.03, 'cash_before': 10028.9848, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 121, 'asset': 'VALE3', 'action': 'Buy', 'price': 74.41, 'cash_before': 10028.9848, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 122, 'asset': 'BRFS3', 'action': 'Sell', 'price': 15.54, 'cash_before': 9939.70561, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 122, 'asset': 'PETR4', 'action': 'Sell', 'price': 27.98, 'cash_before': 9939.70561, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 123, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.65, 'cash_before': 9983.182090000002, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 123, 'asset': 'PETR4', 'action': 'Sell', 'price': 27.55, 'cash_before': 9983.182090000002, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 123, 'asset': 'VALE3', 'action': 'Buy', 'price': 74.58, 'cash_before': 9983.182090000002, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 124, 'asset': 'BRFS3', 'action': 'Sell', 'price': 15.59, 'cash_before': 9967.516440000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 124, 'asset': 'PETR4', 'action': 'Buy', 'price': 28.58, 'cash_before': 9967.516440000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 124, 'asset': 'VALE3', 'action': 'Sell', 'price': 77.53, 'cash_before': 9967.516440000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 125, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.69, 'cash_before': 10031.93474, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 125, 'asset': 'PETR4', 'action': 'Sell', 'price': 28.68, 'cash_before': 10031.93474, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 125, 'asset': 'VALE3', 'action': 'Sell', 'price': 76.15, 'cash_before': 10031.93474, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 126, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.58, 'cash_before': 10044.88037, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 126, 'asset': 'PETR4', 'action': 'Sell', 'price': 28.56, 'cash_before': 10044.88037, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 126, 'asset': 'VALE3', 'action': 'Sell', 'price': 73.03, 'cash_before': 10044.88037, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 127, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.71, 'cash_before': 10044.88037, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 127, 'asset': 'PETR4', 'action': 'Buy', 'price': 28.19, 'cash_before': 10044.88037, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 128, 'asset': 'BRFS3', 'action': 'Sell', 'price': 16.18, 'cash_before': 10016.662180000001, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 128, 'asset': 'PETR4', 'action': 'Sell', 'price': 28.27, 'cash_before': 10016.662180000001, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 128, 'asset': 'VALE3', 'action': 'Sell', 'price': 72.91, 'cash_before': 10016.662180000001, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 129, 'asset': 'BRFS3', 'action': 'Buy', 'price': 16.28, 'cash_before': 10061.06773, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 129, 'asset': 'PETR4', 'action': 'Buy', 'price': 27.52, 'cash_before': 10061.06773, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 129, 'asset': 'VALE3', 'action': 'Sell', 'price': 68.58, 'cash_before': 10061.06773, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 130, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.69, 'cash_before': 10017.22393, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 130, 'asset': 'PETR4', 'action': 'Sell', 'price': 27.83, 'cash_before': 10017.22393, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 130, 'asset': 'VALE3', 'action': 'Sell', 'price': 67.72, 'cash_before': 10017.22393, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 131, 'asset': 'PETR4', 'action': 'Buy', 'price': 28.52, 'cash_before': 10045.026100000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 132, 'asset': 'PETR4', 'action': 'Buy', 'price': 28.96, 'cash_before': 10016.47758, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 132, 'asset': 'VALE3', 'action': 'Sell', 'price': 68.69, 'cash_before': 10016.47758, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 133, 'asset': 'PETR4', 'action': 'Sell', 'price': 29.03, 'cash_before': 10016.47758, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 134, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.19, 'cash_before': 10045.47855, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 134, 'asset': 'PETR4', 'action': 'Buy', 'price': 28.54, 'cash_before': 10045.47855, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 134, 'asset': 'VALE3', 'action': 'Buy', 'price': 67.98, 'cash_before': 10045.47855, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 135, 'asset': 'PETR4', 'action': 'Sell', 'price': 29.23, 'cash_before': 9948.86203, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 136, 'asset': 'BRFS3', 'action': 'Buy', 'price': 16.19, 'cash_before': 9978.0628, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 136, 'asset': 'PETR4', 'action': 'Buy', 'price': 30.28, 'cash_before': 9978.0628, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 136, 'asset': 'VALE3', 'action': 'Sell', 'price': 70.51, 'cash_before': 9978.0628, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 137, 'asset': 'PETR4', 'action': 'Sell', 'price': 31.11, 'cash_before': 10018.19201, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 138, 'asset': 'BRFS3', 'action': 'Sell', 'price': 16.16, 'cash_before': 10049.270900000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 138, 'asset': 'PETR4', 'action': 'Buy', 'price': 31.02, 'cash_before': 10049.270900000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 139, 'asset': 'BRFS3', 'action': 'Sell', 'price': 16.18, 'cash_before': 10034.363720000001, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 139, 'asset': 'PETR4', 'action': 'Buy', 'price': 32.08, 'cash_before': 10034.363720000001, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 140, 'asset': 'BRFS3', 'action': 'Buy', 'price': 15.95, 'cash_before': 10034.363720000001, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 140, 'asset': 'PETR4', 'action': 'Sell', 'price': 34.0, 'cash_before': 10034.363720000001, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 141, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.62, 'cash_before': 10052.363770000002, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 142, 'asset': 'BRFS3', 'action': 'Buy', 'price': 16.52, 'cash_before': 10018.710150000003, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 142, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.89, 'cash_before': 10018.710150000003, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 142, 'asset': 'VALE3', 'action': 'Buy', 'price': 69.14, 'cash_before': 10018.710150000003, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 143, 'asset': 'PETR4', 'action': 'Buy', 'price': 33.87, 'cash_before': 9949.501010000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 143, 'asset': 'VALE3', 'action': 'Sell', 'price': 68.43, 'cash_before': 9949.501010000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 144, 'asset': 'PETR4', 'action': 'Buy', 'price': 34.03, 'cash_before': 10017.86258, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 144, 'asset': 'VALE3', 'action': 'Buy', 'price': 67.41, 'cash_before': 10017.86258, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 145, 'asset': 'PETR4', 'action': 'Sell', 'price': 34.72, 'cash_before': 9950.385170000001, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 146, 'asset': 'BRFS3', 'action': 'Buy', 'price': 17.2, 'cash_before': 9985.070450000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 146, 'asset': 'PETR4', 'action': 'Buy', 'price': 36.2, 'cash_before': 9985.070450000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 146, 'asset': 'VALE3', 'action': 'Sell', 'price': 68.34, 'cash_before': 9985.070450000001, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 147, 'asset': 'BRFS3', 'action': 'Buy', 'price': 16.68, 'cash_before': 10017.105910000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 147, 'asset': 'PETR4', 'action': 'Buy', 'price': 37.15, 'cash_before': 10017.105910000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 148, 'asset': 'BRFS3', 'action': 'Sell', 'price': 17.08, 'cash_before': 10017.105910000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 148, 'asset': 'VALE3', 'action': 'Buy', 'price': 69.81, 'cash_before': 10017.105910000002, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 149, 'asset': 'PETR4', 'action': 'Sell', 'price': 36.86, 'cash_before': 9964.289020000002, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 150, 'asset': 'BRFS3', 'action': 'Sell', 'price': 15.53, 'cash_before': 10001.112160000002, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 150, 'asset': 'VALE3', 'action': 'Sell', 'price': 69.16, 'cash_before': 10001.112160000002, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 151, 'asset': 'PETR4', 'action': 'Buy', 'price': 31.47, 'cash_before': 10070.203000000003, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 151, 'asset': 'VALE3', 'action': 'Buy', 'price': 67.99, 'cash_before': 10070.203000000003, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 152, 'asset': 'VALE3', 'action': 'Sell', 'price': 69.77, 'cash_before': 9970.643540000005, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# ...
# {'step': 721, 'asset': 'PETR4', 'action': 'Buy', 'price': 39.34, 'cash_before': 10080.826959999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 721, 'asset': 'VALE3', 'action': 'Sell', 'price': 58.29, 'cash_before': 10080.826959999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 722, 'asset': 'BRFS3', 'action': 'Buy', 'price': 24.5, 'cash_before': 10099.679329999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 722, 'asset': 'PETR4', 'action': 'Buy', 'price': 39.22, 'cash_before': 10099.679329999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 723, 'asset': 'PETR4', 'action': 'Buy', 'price': 39.01, 'cash_before': 10099.679329999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 723, 'asset': 'VALE3', 'action': 'Buy', 'price': 58.09, 'cash_before': 10099.679329999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 724, 'asset': 'BRFS3', 'action': 'Sell', 'price': 24.81, 'cash_before': 10041.531239999991, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 724, 'asset': 'PETR4', 'action': 'Sell', 'price': 38.8, 'cash_before': 10041.531239999991, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 725, 'asset': 'BRFS3', 'action': 'Buy', 'price': 24.73, 'cash_before': 10105.077629999992, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 726, 'asset': 'BRFS3', 'action': 'Buy', 'price': 24.97, 'cash_before': 10080.322899999992, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 726, 'asset': 'PETR4', 'action': 'Buy', 'price': 39.14, 'cash_before': 10080.322899999992, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 726, 'asset': 'VALE3', 'action': 'Sell', 'price': 59.06, 'cash_before': 10080.322899999992, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 727, 'asset': 'PETR4', 'action': 'Sell', 'price': 39.3, 'cash_before': 10100.144699999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 728, 'asset': 'BRFS3', 'action': 'Buy', 'price': 27.11, 'cash_before': 10139.405399999992, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 728, 'asset': 'PETR4', 'action': 'Buy', 'price': 39.37, 'cash_before': 10139.405399999992, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 728, 'asset': 'VALE3', 'action': 'Buy', 'price': 57.57, 'cash_before': 10139.405399999992, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 729, 'asset': 'BRFS3', 'action': 'Sell', 'price': 27.91, 'cash_before': 10042.368459999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 729, 'asset': 'PETR4', 'action': 'Buy', 'price': 39.57, 'cash_before': 10042.368459999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 729, 'asset': 'VALE3', 'action': 'Buy', 'price': 57.37, 'cash_before': 10042.368459999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 730, 'asset': 'BRFS3', 'action': 'Buy', 'price': 28.28, 'cash_before': 10070.250549999992, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 730, 'asset': 'VALE3', 'action': 'Buy', 'price': 57.06, 'cash_before': 10070.250549999992, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 731, 'asset': 'PETR4', 'action': 'Sell', 'price': 39.85, 'cash_before': 10041.942269999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 732, 'asset': 'BRFS3', 'action': 'Sell', 'price': 28.0, 'cash_before': 10081.752419999992, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 732, 'asset': 'PETR4', 'action': 'Buy', 'price': 40.25, 'cash_before': 10081.752419999992, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 732, 'asset': 'VALE3', 'action': 'Sell', 'price': 59.65, 'cash_before': 10081.752419999992, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 733, 'asset': 'BRFS3', 'action': 'Buy', 'price': 28.4, 'cash_before': 10129.024519999992, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 733, 'asset': 'PETR4', 'action': 'Sell', 'price': 40.42, 'cash_before': 10129.024519999992, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 733, 'asset': 'VALE3', 'action': 'Sell', 'price': 58.85, 'cash_before': 10129.024519999992, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 734, 'asset': 'PETR4', 'action': 'Buy', 'price': 38.46, 'cash_before': 10140.975699999992, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 735, 'asset': 'BRFS3', 'action': 'Buy', 'price': 27.92, 'cash_before': 10102.477239999991, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 735, 'asset': 'PETR4', 'action': 'Sell', 'price': 38.16, 'cash_before': 10102.477239999991, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 735, 'asset': 'VALE3', 'action': 'Sell', 'price': 56.01, 'cash_before': 10102.477239999991, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 736, 'asset': 'BRFS3', 'action': 'Buy', 'price': 28.23, 'cash_before': 10140.59907999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 736, 'asset': 'PETR4', 'action': 'Buy', 'price': 38.02, 'cash_before': 10140.59907999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 737, 'asset': 'BRFS3', 'action': 'Sell', 'price': 28.32, 'cash_before': 10102.54105999999, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 737, 'asset': 'PETR4', 'action': 'Sell', 'price': 38.25, 'cash_before': 10102.54105999999, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 737, 'asset': 'VALE3', 'action': 'Sell', 'price': 56.14, 'cash_before': 10102.54105999999, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 738, 'asset': 'BRFS3', 'action': 'Buy', 'price': 27.55, 'cash_before': 10169.044489999991, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 738, 'asset': 'VALE3', 'action': 'Sell', 'price': 55.15, 'cash_before': 10169.044489999991, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 739, 'asset': 'PETR4', 'action': 'Buy', 'price': 37.34, 'cash_before': 10141.466939999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 740, 'asset': 'BRFS3', 'action': 'Buy', 'price': 25.89, 'cash_before': 10104.089599999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 740, 'asset': 'PETR4', 'action': 'Sell', 'price': 36.95, 'cash_before': 10104.089599999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 740, 'asset': 'VALE3', 'action': 'Sell', 'price': 54.34, 'cash_before': 10104.089599999992, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 741, 'asset': 'BRFS3', 'action': 'Sell', 'price': 26.0, 'cash_before': 10141.002649999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 741, 'asset': 'PETR4', 'action': 'Sell', 'price': 36.9, 'cash_before': 10141.002649999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 741, 'asset': 'VALE3', 'action': 'Sell', 'price': 54.84, 'cash_before': 10141.002649999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 742, 'asset': 'BRFS3', 'action': 'Buy', 'price': 25.53, 'cash_before': 10166.976649999991, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 742, 'asset': 'VALE3', 'action': 'Buy', 'price': 54.99, 'cash_before': 10166.976649999991, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 743, 'asset': 'BRFS3', 'action': 'Buy', 'price': 24.74, 'cash_before': 10086.376129999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 743, 'asset': 'PETR4', 'action': 'Buy', 'price': 35.8, 'cash_before': 10086.376129999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 744, 'asset': 'BRFS3', 'action': 'Sell', 'price': 25.36, 'cash_before': 10050.54032999999, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 745, 'asset': 'VALE3', 'action': 'Sell', 'price': 54.52, 'cash_before': 10075.87496999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 746, 'asset': 'BRFS3', 'action': 'Sell', 'price': 24.28, 'cash_before': 10130.34044999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 746, 'asset': 'VALE3', 'action': 'Sell', 'price': 53.36, 'cash_before': 10130.34044999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 747, 'asset': 'BRFS3', 'action': 'Buy', 'price': 23.88, 'cash_before': 10130.34044999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 747, 'asset': 'PETR4', 'action': 'Sell', 'price': 36.26, 'cash_before': 10130.34044999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 747, 'asset': 'VALE3', 'action': 'Sell', 'price': 52.93, 'cash_before': 10130.34044999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 748, 'asset': 'VALE3', 'action': 'Sell', 'price': 52.32, 'cash_before': 10142.66030999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 749, 'asset': 'BRFS3', 'action': 'Buy', 'price': 23.31, 'cash_before': 10142.66030999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 749, 'asset': 'PETR4', 'action': 'Sell', 'price': 36.7, 'cash_before': 10142.66030999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 749, 'asset': 'VALE3', 'action': 'Sell', 'price': 51.67, 'cash_before': 10142.66030999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 750, 'asset': 'VALE3', 'action': 'Sell', 'price': 51.66, 'cash_before': 10142.66030999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 751, 'asset': 'BRFS3', 'action': 'Sell', 'price': 23.4, 'cash_before': 10142.66030999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 751, 'asset': 'PETR4', 'action': 'Buy', 'price': 37.19, 'cash_before': 10142.66030999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 751, 'asset': 'VALE3', 'action': 'Buy', 'price': 51.7, 'cash_before': 10142.66030999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 752, 'asset': 'BRFS3', 'action': 'Buy', 'price': 23.39, 'cash_before': 10077.05801999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 752, 'asset': 'VALE3', 'action': 'Sell', 'price': 51.59, 'cash_before': 10077.05801999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 1}}
# {'step': 753, 'asset': 'PETR4', 'action': 'Sell', 'price': 36.84, 'cash_before': 10105.183039999989, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 0}}
# {'step': 754, 'asset': 'BRFS3', 'action': 'Sell', 'price': 24.02, 'cash_before': 10141.986199999988, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 754, 'asset': 'PETR4', 'action': 'Sell', 'price': 37.13, 'cash_before': 10141.986199999988, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 755, 'asset': 'BRFS3', 'action': 'Buy', 'price': 22.97, 'cash_before': 10165.982179999988, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 755, 'asset': 'VALE3', 'action': 'Buy', 'price': 52.34, 'cash_before': 10165.982179999988, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 756, 'asset': 'PETR4', 'action': 'Buy', 'price': 37.2, 'cash_before': 10090.596869999988, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 756, 'asset': 'VALE3', 'action': 'Buy', 'price': 54.08, 'cash_before': 10090.596869999988, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 757, 'asset': 'BRFS3', 'action': 'Sell', 'price': 23.28, 'cash_before': 10053.359669999989, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 757, 'asset': 'PETR4', 'action': 'Sell', 'price': 37.27, 'cash_before': 10053.359669999989, 'positions_before': {'BRFS3': 1, 'PETR4': 1, 'VALE3': 1}}
# {'step': 758, 'asset': 'PETR4', 'action': 'Sell', 'price': 37.06, 'cash_before': 10113.849119999988, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 759, 'asset': 'VALE3', 'action': 'Sell', 'price': 53.22, 'cash_before': 10113.849119999988, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 760, 'asset': 'BRFS3', 'action': 'Buy', 'price': 21.89, 'cash_before': 10167.015899999988, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 760, 'asset': 'VALE3', 'action': 'Sell', 'price': 52.27, 'cash_before': 10167.015899999988, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 761, 'asset': 'VALE3', 'action': 'Sell', 'price': 52.93, 'cash_before': 10145.104009999988, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 762, 'asset': 'BRFS3', 'action': 'Sell', 'price': 22.23, 'cash_before': 10145.104009999988, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 762, 'asset': 'VALE3', 'action': 'Buy', 'price': 53.58, 'cash_before': 10145.104009999988, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 763, 'asset': 'VALE3', 'action': 'Sell', 'price': 52.93, 'cash_before': 10113.67819999999, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 765, 'asset': 'PETR4', 'action': 'Buy', 'price': 37.28, 'cash_before': 10166.55526999999, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 766, 'asset': 'BRFS3', 'action': 'Sell', 'price': 22.02, 'cash_before': 10129.23798999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 766, 'asset': 'PETR4', 'action': 'Sell', 'price': 37.84, 'cash_before': 10129.23798999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 766, 'asset': 'VALE3', 'action': 'Buy', 'price': 54.48, 'cash_before': 10129.23798999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 767, 'asset': 'PETR4', 'action': 'Sell', 'price': 37.56, 'cash_before': 10112.50566999999, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 767, 'asset': 'VALE3', 'action': 'Buy', 'price': 53.9, 'cash_before': 10112.50566999999, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 768, 'asset': 'BRFS3', 'action': 'Sell', 'price': 20.76, 'cash_before': 10112.50566999999, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 768, 'asset': 'VALE3', 'action': 'Sell', 'price': 54.09, 'cash_before': 10112.50566999999, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 1}}
# {'step': 769, 'asset': 'BRFS3', 'action': 'Buy', 'price': 20.75, 'cash_before': 10166.54157999999, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 769, 'asset': 'PETR4', 'action': 'Sell', 'price': 36.89, 'cash_before': 10166.54157999999, 'positions_before': {'BRFS3': 0, 'PETR4': 0, 'VALE3': 0}}
# {'step': 770, 'asset': 'VALE3', 'action': 'Buy', 'price': 55.25, 'cash_before': 10145.77082999999, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 0}}
# {'step': 771, 'asset': 'BRFS3', 'action': 'Sell', 'price': 20.77, 'cash_before': 10090.465579999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 771, 'asset': 'PETR4', 'action': 'Buy', 'price': 36.57, 'cash_before': 10090.465579999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 771, 'asset': 'VALE3', 'action': 'Sell', 'price': 55.0, 'cash_before': 10090.465579999991, 'positions_before': {'BRFS3': 1, 'PETR4': 0, 'VALE3': 1}}
# {'step': 772, 'asset': 'BRFS3', 'action': 'Buy', 'price': 21.34, 'cash_before': 10129.55323999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 772, 'asset': 'PETR4', 'action': 'Buy', 'price': 36.88, 'cash_before': 10129.55323999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
# {'step': 772, 'asset': 'VALE3', 'action': 'Sell', 'price': 55.12, 'cash_before': 10129.55323999999, 'positions_before': {'BRFS3': 0, 'PETR4': 1, 'VALE3': 0}}
